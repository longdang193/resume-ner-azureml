# %% [markdown]
# # Testing Orchestration Notebook
#
# This notebook provides an interactive way to run, manage, and explore the test suite for the Resume NER training pipeline.
#
# ## Overview
#
# - **Step 1**: Setup and Environment Verification
# - **Step 2**: Run All Tests
# - **Step 3**: Run Specific Test Suites
# - **Step 4**: Generate Coverage Reports
# - **Step 5**: Run Troubleshooting Prevention Tests
# - **Step 6**: Explore Test Results
#
# ## Important
#
# - Tests can be run locally or in CI/CD pipelines
# - This notebook provides interactive exploration and visualization
# - All tests use pytest framework
# - Coverage reports are generated in HTML format for easy viewing
# - **YAML Configuration**: Test settings are loaded from `config/test/*.yaml` files
#   - Coverage thresholds are automatically enforced
#   - Test fixtures and mocks are configured via YAML
#   - See `tests/README_YAML_CONFIG.md` for details

# %% [markdown]
# ## Step 1: Setup and Environment Verification
#
# Verify that the testing environment is properly configured and all dependencies are installed.

# %%
import os
import sys
from pathlib import Path

NOTEBOOK_DIR = Path.cwd()
ROOT_DIR = NOTEBOOK_DIR.parent
SRC_DIR = ROOT_DIR / "src"
TESTS_DIR = ROOT_DIR / "tests"

sys.path.append(str(ROOT_DIR))
sys.path.append(str(SRC_DIR))
sys.path.append(str(TESTS_DIR))

os.chdir(ROOT_DIR)

# %%
REQUIRED_PATHS = {
    "tests/": TESTS_DIR,
    "tests/conftest.py": TESTS_DIR / "conftest.py",
    "tests/unit/": TESTS_DIR / "unit",
    "tests/integration/": TESTS_DIR / "integration",
    "pytest.ini": ROOT_DIR / "pytest.ini",
}

missing_paths = [name for name, path in REQUIRED_PATHS.items() if not path.exists()]
if missing_paths:
    raise FileNotFoundError(f"Missing test files/directories: {', '.join(missing_paths)}")

# %%
# Install test dependencies if needed
# Uncomment the line below if pytest, pytest-cov, or pytest-mock are not installed
# %pip install -q pytest pytest-cov pytest-mock pytest-xdist

# %%
import pytest

try:
    import pytest_cov
except ImportError:
    pytest_cov = None

try:
    import pytest_mock
except ImportError:
    pytest_mock = None

# %% [markdown]
# ## Step 2: Run All Tests
#
# Run the complete test suite to verify all components are working correctly.

# %%
import subprocess
import os

def run_tests(test_path, *args):
    """Run pytest and display clear success/failure status."""
    root_dir_abs = str(ROOT_DIR.resolve())
    src_dir_abs = str(SRC_DIR.resolve())
    test_path_abs = str((ROOT_DIR / test_path).resolve())
    
    cmd = ["pytest", test_path_abs] + list(args)
    env = os.environ.copy()
    pythonpath = src_dir_abs
    if "PYTHONPATH" in env:
        env["PYTHONPATH"] = f"{pythonpath}{os.pathsep}{env['PYTHONPATH']}"
    else:
        env["PYTHONPATH"] = pythonpath
    
    result = subprocess.run(cmd, cwd=root_dir_abs, env=env, capture_output=True, text=True)
    
    print(result.stdout)
    if result.stderr:
        print("STDERR:", result.stderr)
    
    if result.returncode == 0:
        print("\n✓ All tests passed")
    elif result.returncode == 1:
        print("\n✗ Tests failed - see output above")
    elif result.returncode == 2:
        print("\n✗ Test collection errors - check import errors above")
    elif result.returncode == 4:
        print("\n✗ No tests collected - check import errors above")
    else:
        print(f"\n✗ Test execution error (return code: {result.returncode})")
    
    return result

# %% [markdown]
# ### Run Complete Test Suite
#
# Executes all tests to verify the entire codebase functionality.

# %%
run_tests("tests/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 375 items
#
# tests/integration/test_train.py::TestParseArguments::test_parse_required_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_all_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_use_all_data PASSED [  0%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none PASSED [  1%]
# tests/integration/test_train.py::TestMain::test_main_success PASSED      [  1%]
# tests/integration/test_train.py::TestMain::test_main_config_dir_not_found PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_with_overrides PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_uses_platform_adapter PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [ 10%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_extract_best_config PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_empty_study_raises_error PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_excludes_backbone_from_params PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_includes_cv_statistics PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_minimize PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_no_valid_trials_raises_error PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_choice_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_uniform_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_loguniform_distribution PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_multiple_parameters PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_create_median_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_early_termination PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_success PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_failure PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_fallback_to_mlflow PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_no_metrics PASSED [ 15%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_missing_objective_metric PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_success PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_failed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_canceled_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_streams_logs PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_returns_completed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_selection.py::TestConfigureMlflow::test_configure_mlflow_sets_tracking_uri PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_success PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_empty PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_error_handling PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_success PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_empty PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_error_handling PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_maximize PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_minimize PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_no_completed_trials PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_missing_metric PASSED [ 19%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_choice PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_uniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_loguniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_multiple_params PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 21%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_hpo_overrides PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_defaults PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_custom_seed PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_empty_hyperparameters PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_missing_training_section PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_success PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_failed_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_canceled_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_success PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_script_not_found PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_command_args PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_uses_asset_reference PASSED [ 25%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_outputs_checkpoint PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_missing_experiment_file PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_invalid_yaml_structure PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_experiment_name_override PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_default_experiment_name PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_all_configs_loaded PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_config_structure PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_deterministic_hashing PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_different_configs_different_hashes PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_hash_length PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_order_independent PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_nested_configs PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_all_configs_hashed PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_hash_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_structure PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_snapshot_configs PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_unchanged_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_mutated_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_multiple_mutations PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_local_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_default PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_absolute_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_non_string PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_list PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_existing_asset PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_local_path PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_datastore_uri PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_http_uri PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_path_resolution_error PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_datastore_path PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_local_path_match PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_new_asset_creation PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_race_condition PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_fallback_to_input PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_path_normalization_string_comparison PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_without_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_trailing_slash PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_extracts_relative_path PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_defaults PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_custom_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_partial_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_empty_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_none_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_success PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_file_not_found PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_deterministic PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_inputs PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_docker_images PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_includes_both_inputs PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_get_existing_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_create_new_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestCreateTrainingEnvironment::test_create_training_environment_success PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_existing_completed_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_no_matching_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_warmup_failed PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_list_jobs_failure PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_respects_history_limit PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_existing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_missing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_empty_config PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_none_config PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_without_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_different_stages PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_special_characters PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_empty_strings PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter PASSED [ 47%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_nonexistent_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_traversal_error PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_success PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_nonexistent_path PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_traversal_error PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_with_azureml PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_with_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_metrics PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_params PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_named_output PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_generic PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_default PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_current_dir PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory_existing PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_provided_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_no_default PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_existing PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_nested PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json PASSED [ 61%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_required_arguments PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_optional_flags PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_success PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_failure PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_2d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_1d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_mixed_tensors PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_fp32 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_int8 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_export_failure PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_quantization_fallback PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_success PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_import_error PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_no_output PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_success PASSED   [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_with_smoke_test PASSED [ 67%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_config_dir_not_found PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file PASSED [ 68%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_val_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_round_trip_serialization PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_metadata_preserved PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_no_metadata PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_file_not_found PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_invalid_file_format PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_multiple_folds PASSED [ 76%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_directory_creation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_train_only PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_with_validation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_dataset_path PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_train_file PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_invalid_json PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_string_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_list_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_tuple_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_nested_list PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_dict_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_none_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_number_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_empty_list PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_perfect_alignment PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_no_annotations PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_partial_overlap PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_multiple_annotations_per_token PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_annotation_beyond_text PASSED [ 81%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_token_beyond_annotation PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_standard_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_empty_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_sorted_order PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_len PASSED  [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_fast_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_no_annotations PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_truncation PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_basic PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_with_mask PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_multiple_samples PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_unknown_label_id PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_empty_after_mask PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_success PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_multiple_batches PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_zero_loss PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_empty_dataloader PASSED [ 86%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_uses_no_grad PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_file PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_directory PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_calls_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_default_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_empty_dict PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_nested_values PASSED [ 88%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_overwrites_existing_file PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_perfect_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_no_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_partial_match PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_empty_lists PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_label_not_present PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_positives PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_negatives PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_multiple_labels PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_single_label PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_predictions PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_imbalanced_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_complete_metrics PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_zero_loss PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_all_metrics_are_floats PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_empty_labels PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_basic PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_with_indices PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_use_all_data PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_deberta_batch_size_cap PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_val_split_fallback PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_defaults PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_custom PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_warmup_capped PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_basic PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_multiple_epochs PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_success PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_creates_directory PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_basic PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_with_fold_splits PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_use_all_data PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx PASSED [ 97%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_value PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_none PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_zero PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_negative PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_multiple_calls PASSED [100%]
#
# ===================== 375 passed, 478 warnings in 24.00s ======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 375 items\n\ntests/integration/test_train.py::TestParseArguments::test_parse_required_arguments \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_all_arguments \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_use_all_data \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestMain::test_main_success \x1bPASSED\x1b\x1b      [  1%]\x1b\ntests/integration/test_train.py::TestMain::test_main_config_dir_not_found \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_train.py::TestMain::test_main_with_overrides \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_train.py::TestMain::test_main_uses_platform_adapter \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversio ...

# %% [markdown]
# ### Unit Tests
#
# Fast, isolated tests for individual components. Tests pure functions, data loading, configuration, and utilities without external dependencies.

# %%
run_tests("tests/unit/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 357 items
#
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  0%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  0%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [  0%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [  1%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [  1%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [  1%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [  1%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [  2%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [  2%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [  2%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [  3%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [  3%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [  3%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [  3%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [  5%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_extract_best_config PASSED [  6%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_empty_study_raises_error PASSED [  6%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_excludes_backbone_from_params PASSED [  6%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_includes_cv_statistics PASSED [  7%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize PASSED [  7%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_minimize PASSED [  7%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_no_valid_trials_raises_error PASSED [  7%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_choice_distribution PASSED [  8%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_uniform_distribution PASSED [  8%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_loguniform_distribution PASSED [  8%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_multiple_parameters PASSED [  8%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_create_median_pruner PASSED [  9%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_pruner PASSED [  9%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_early_termination PASSED [  9%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_success PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_failure PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_fallback_to_mlflow PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_no_metrics PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_missing_objective_metric PASSED [ 11%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_success PASSED [ 11%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_failed_job PASSED [ 11%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_canceled_job PASSED [ 12%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_streams_logs PASSED [ 12%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_returns_completed_job PASSED [ 12%]
# tests/unit/orchestration/jobs/test_selection.py::TestConfigureMlflow::test_configure_mlflow_sets_tracking_uri PASSED [ 12%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_success PASSED [ 13%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_empty PASSED [ 13%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_error_handling PASSED [ 13%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_success PASSED [ 14%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_empty PASSED [ 14%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_error_handling PASSED [ 14%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_maximize PASSED [ 14%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_minimize PASSED [ 15%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_no_completed_trials PASSED [ 15%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_missing_metric PASSED [ 15%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_choice PASSED [ 15%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_uniform PASSED [ 16%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_loguniform PASSED [ 16%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_multiple_params PASSED [ 16%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 17%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 17%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_hpo_overrides PASSED [ 17%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_defaults PASSED [ 17%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_custom_seed PASSED [ 18%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_empty_hyperparameters PASSED [ 18%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_missing_training_section PASSED [ 18%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_success PASSED [ 19%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_failed_job PASSED [ 19%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_canceled_job PASSED [ 19%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 19%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 20%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_success PASSED [ 20%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_script_not_found PASSED [ 20%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_command_args PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_uses_asset_reference PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_outputs_checkpoint PASSED [ 21%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config PASSED [ 21%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_missing_experiment_file PASSED [ 22%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_invalid_yaml_structure PASSED [ 22%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_experiment_name_override PASSED [ 22%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_default_experiment_name PASSED [ 22%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_all_configs_loaded PASSED [ 23%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_config_structure PASSED [ 23%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_deterministic_hashing PASSED [ 23%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_different_configs_different_hashes PASSED [ 24%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_hash_length PASSED [ 24%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_order_independent PASSED [ 24%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_nested_configs PASSED [ 24%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_all_configs_hashed PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_hash_values_are_strings PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_structure PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_values_are_strings PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_snapshot_configs PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_unchanged_configs PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_mutated_configs PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_multiple_mutations PASSED [ 27%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 27%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 27%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 28%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [ 28%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_local_path PASSED [ 28%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_default PASSED [ 28%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_absolute_path PASSED [ 29%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_non_string PASSED [ 29%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_list PASSED [ 29%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_existing_asset PASSED [ 29%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_local_path PASSED [ 30%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_datastore_uri PASSED [ 30%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_http_uri PASSED [ 30%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_path_resolution_error PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_datastore_path PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_local_path_match PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_new_asset_creation PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_race_condition PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_fallback_to_input PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_path_normalization_string_comparison PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_datastore_path PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_without_datastore_path PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_trailing_slash PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_extracts_relative_path PASSED [ 33%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_defaults PASSED [ 34%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_custom_settings PASSED [ 34%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_partial_settings PASSED [ 34%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_empty_env_section PASSED [ 35%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_none_env_section PASSED [ 35%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_success PASSED [ 35%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_file_not_found PASSED [ 35%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_deterministic PASSED [ 36%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_inputs PASSED [ 36%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_docker_images PASSED [ 36%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_includes_both_inputs PASSED [ 36%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_get_existing_environment PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_create_new_environment PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestCreateTrainingEnvironment::test_create_training_environment_success PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_existing_completed_job PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_no_matching_job PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_warmup_failed PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_list_jobs_failure PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_respects_history_limit PASSED [ 39%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_existing_stage PASSED [ 39%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_missing_stage PASSED [ 39%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_empty_config PASSED [ 40%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_none_config PASSED [ 40%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_backbone PASSED [ 40%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_without_backbone PASSED [ 40%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_different_stages PASSED [ 41%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_special_characters PASSED [ 41%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_empty_strings PASSED [ 41%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter PASSED [ 42%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter PASSED [ 42%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir PASSED [ 42%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job PASSED [ 42%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job PASSED [ 43%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver PASSED [ 43%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter PASSED [ 43%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job PASSED [ 43%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir PASSED [ 44%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 45%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 45%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt PASSED [ 45%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 45%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 46%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config PASSED [ 46%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file PASSED [ 46%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_nonexistent_path PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_traversal_error PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_success PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_nonexistent_path PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_traversal_error PASSED [ 50%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_with_azureml PASSED [ 50%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_without_azureml PASSED [ 50%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_with_azureml PASSED [ 50%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_without_azureml PASSED [ 51%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_metrics PASSED [ 51%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_params PASSED [ 51%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 52%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 52%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 52%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 52%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 53%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [ 53%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_named_output PASSED [ 53%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_generic PASSED [ 54%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_default PASSED [ 54%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_current_dir PASSED [ 54%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory PASSED [ 54%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory_existing PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_default PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_provided_default PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_no_default PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_existing PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_nested PASSED [ 56%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict PASSED [ 57%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict PASSED [ 57%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory PASSED [ 57%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing PASSED [ 57%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file PASSED [ 59%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml PASSED [ 59%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml PASSED [ 59%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found PASSED [ 60%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml PASSED [ 60%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml PASSED [ 60%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments PASSED [ 61%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_required_arguments PASSED [ 61%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_optional_flags PASSED [ 61%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_success PASSED [ 61%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_failure PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_2d_tensor PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_1d_tensor PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_mixed_tensors PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_fp32 PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_int8 PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_export_failure PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_quantization_fallback PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_success PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_import_error PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_no_output PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_success PASSED   [ 65%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_with_smoke_test PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_config_dir_not_found PASSED [ 65%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading PASSED [ 66%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file PASSED [ 66%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure PASSED [ 66%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override PASSED [ 66%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override PASSED [ 67%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override PASSED [ 67%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override PASSED [ 67%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides PASSED [ 69%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 PASSED [ 70%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 PASSED [ 70%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap PASSED [ 70%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used PASSED [ 70%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_indices PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_val_indices PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_round_trip_serialization PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_metadata_preserved PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_no_metadata PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_file_not_found PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_invalid_file_format PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_multiple_folds PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_directory_creation PASSED [ 75%]
# tests/unit/training/test_data.py::TestLoadDataset::test_train_only PASSED [ 75%]
# tests/unit/training/test_data.py::TestLoadDataset::test_with_validation PASSED [ 75%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_dataset_path PASSED [ 75%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_train_file PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_invalid_json PASSED [ 76%]
# tests/unit/training/test_data.py::TestNormalizeText::test_string_input PASSED [ 76%]
# tests/unit/training/test_data.py::TestNormalizeText::test_list_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_tuple_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_nested_list PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_dict_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_none_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_number_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_empty_list PASSED [ 78%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_perfect_alignment PASSED [ 78%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_no_annotations PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_partial_overlap PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_multiple_annotations_per_token PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_annotation_beyond_text PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_token_beyond_annotation PASSED [ 80%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_standard_entity_types PASSED [ 80%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_empty_entity_types PASSED [ 80%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_sorted_order PASSED [ 81%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_len PASSED  [ 81%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_fast_tokenizer PASSED [ 81%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_no_annotations PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_truncation PASSED [ 82%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_basic PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_with_mask PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_multiple_samples PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_unknown_label_id PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_empty_after_mask PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_success PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_multiple_batches PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_zero_loss PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_empty_dataloader PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_uses_no_grad PASSED [ 85%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_file PASSED [ 85%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_directory PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_calls_adapter PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_default_adapter PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_empty_dict PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_nested_values PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_overwrites_existing_file PASSED [ 87%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_perfect_match PASSED [ 87%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_no_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_partial_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_empty_lists PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_label_not_present PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_positives PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_negatives PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_multiple_labels PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_single_label PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_predictions PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_labels PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_imbalanced_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_complete_metrics PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_zero_loss PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_all_metrics_are_floats PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_empty_labels PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_basic PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_with_indices PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_use_all_data PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_deberta_batch_size_cap PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_val_split_fallback PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_defaults PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_custom PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_warmup_capped PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_basic PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_multiple_epochs PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_success PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_creates_directory PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_basic PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_with_fold_splits PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_use_all_data PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx PASSED [ 97%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_value PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_none PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_zero PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_negative PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_multiple_calls PASSED [100%]
#
# ===================== 357 passed, 478 warnings in 21.19s ======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests\\unit', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 357 items\n\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/un ...

# %% [markdown]
# ## Step 3: Run Specific Test Suites
#
# Run tests for specific components or categories.

# %% [markdown]
# ### Integration Tests
#
# Tests component interactions and workflows. Verifies end-to-end behavior and cross-component integration.

# %%
run_tests("tests/integration/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 18 items
#
# tests/integration/test_train.py::TestParseArguments::test_parse_required_arguments PASSED [  5%]
# tests/integration/test_train.py::TestParseArguments::test_parse_all_arguments PASSED [ 11%]
# tests/integration/test_train.py::TestParseArguments::test_parse_use_all_data PASSED [ 16%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params PASSED [ 22%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params PASSED [ 27%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none PASSED [ 33%]
# tests/integration/test_train.py::TestMain::test_main_success PASSED      [ 38%]
# tests/integration/test_train.py::TestMain::test_main_config_dir_not_found PASSED [ 44%]
# tests/integration/test_train.py::TestMain::test_main_with_overrides PASSED [ 50%]
# tests/integration/test_train.py::TestMain::test_main_uses_platform_adapter PASSED [ 55%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root PASSED [ 61%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error PASSED [ 66%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference PASSED [ 72%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference PASSED [ 77%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run PASSED [ 83%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run PASSED [ 88%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories PASSED [ 94%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files PASSED [100%]
#
# ====================== 18 passed, 470 warnings in 13.25s ======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests\\integration', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 18 items\n\ntests/integration/test_train.py::TestParseArguments::test_parse_required_arguments \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_all_arguments \x1bPASSED\x1b\x1b [ 11%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_use_all_data \x1bPASSED\x1b\x1b [ 16%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params \x1bPASSED\x1b\x1b [ 22%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params \x1bPASSED\x1b\x1b [ 27%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none \x1bPASSED\x1b\x1b [ 33%]\x1b\ntests/integration/test_train.py::TestMain::test_main_success \x1bPASSED\x1b\x1b      [ 38%]\x1b\ntests/integration/test_train.py::TestMain::test_main_config_dir_not_found \x1bPASSED\x1b\x1b [ 44%]\x1b\ntests/integration/test_train.py::TestMain::test_main_with_overrides \x1bPASSED\x1b\x1b [ 50%]\x1b\ntests/integration/test_train.py::TestMain::test_main_uses_platform_adapter \x1bPASSED\x1b\x1b [ 55%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root \x1bPASSED\x1b\x1b [ 61%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error \x1bPASSED\x1b\x1b [ 66%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference \x1bPASSED\x1b\x1b [ 72%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference \x1bPASSED\x1b\x1b [ 77%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run \x1bPASSED\x1b\x1b [ 83%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run \x1bPASSED\x1b\x1b [ 88%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories \x1bPASSED\x1b\x1b [ 94%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files \x1bPASSED\x1b\x1b [100%]\x1b\n\n\x1b====================== \x1b18 passed\x1b, \x1b\x1b470 warnings\x1b\x1b in 13.25s\x1b\x1b ======================\x1b\n', stderr='')

# %% [markdown]
# ### Training Component Tests
#
# Tests for training-specific functionality: metrics computation, data loading, cross-validation, and model configuration.

# %%
run_tests("tests/unit/training/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 122 items
#
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading PASSED [  0%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file PASSED [  1%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure PASSED [  2%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override PASSED [  3%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override PASSED [  4%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override PASSED [  4%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override PASSED [  5%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override PASSED [  6%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override PASSED [  7%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true PASSED [  8%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false PASSED [  9%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override PASSED [  9%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override PASSED [ 10%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides PASSED [ 11%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 PASSED [ 12%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 PASSED [ 13%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap PASSED [ 13%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used PASSED [ 14%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size PASSED [ 15%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility PASSED [ 16%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits PASSED [ 17%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle PASSED [ 18%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction PASSED [ 18%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match PASSED [ 19%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_indices PASSED [ 20%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_val_indices PASSED [ 21%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_round_trip_serialization PASSED [ 22%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_metadata_preserved PASSED [ 22%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_no_metadata PASSED [ 23%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_file_not_found PASSED [ 24%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_invalid_file_format PASSED [ 25%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_multiple_folds PASSED [ 26%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_directory_creation PASSED [ 27%]
# tests/unit/training/test_data.py::TestLoadDataset::test_train_only PASSED [ 27%]
# tests/unit/training/test_data.py::TestLoadDataset::test_with_validation PASSED [ 28%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_dataset_path PASSED [ 29%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_train_file PASSED [ 30%]
# tests/unit/training/test_data.py::TestLoadDataset::test_invalid_json PASSED [ 31%]
# tests/unit/training/test_data.py::TestNormalizeText::test_string_input PASSED [ 31%]
# tests/unit/training/test_data.py::TestNormalizeText::test_list_input PASSED [ 32%]
# tests/unit/training/test_data.py::TestNormalizeText::test_tuple_input PASSED [ 33%]
# tests/unit/training/test_data.py::TestNormalizeText::test_nested_list PASSED [ 34%]
# tests/unit/training/test_data.py::TestNormalizeText::test_dict_input PASSED [ 35%]
# tests/unit/training/test_data.py::TestNormalizeText::test_none_input PASSED [ 36%]
# tests/unit/training/test_data.py::TestNormalizeText::test_number_input PASSED [ 36%]
# tests/unit/training/test_data.py::TestNormalizeText::test_empty_list PASSED [ 37%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_perfect_alignment PASSED [ 38%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_no_annotations PASSED [ 39%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_partial_overlap PASSED [ 40%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_multiple_annotations_per_token PASSED [ 40%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_annotation_beyond_text PASSED [ 41%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_token_beyond_annotation PASSED [ 42%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_standard_entity_types PASSED [ 43%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_empty_entity_types PASSED [ 44%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_sorted_order PASSED [ 45%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_len PASSED  [ 45%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_fast_tokenizer PASSED [ 46%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer PASSED [ 47%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text PASSED [ 48%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_no_annotations PASSED [ 49%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_truncation PASSED [ 50%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_basic PASSED [ 50%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_with_mask PASSED [ 51%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_multiple_samples PASSED [ 52%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_unknown_label_id PASSED [ 53%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_empty_after_mask PASSED [ 54%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_success PASSED [ 54%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_multiple_batches PASSED [ 55%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_zero_loss PASSED [ 56%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_empty_dataloader PASSED [ 57%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_uses_no_grad PASSED [ 58%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_file PASSED [ 59%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_directory PASSED [ 59%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_calls_adapter PASSED [ 60%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_default_adapter PASSED [ 61%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_empty_dict PASSED [ 62%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_nested_values PASSED [ 63%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_overwrites_existing_file PASSED [ 63%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_perfect_match PASSED [ 64%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_no_match PASSED [ 65%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_partial_match PASSED [ 66%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_empty_lists PASSED [ 67%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_label_not_present PASSED [ 68%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_positives PASSED [ 68%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_negatives PASSED [ 69%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_multiple_labels PASSED [ 70%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_single_label PASSED [ 71%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_predictions PASSED [ 72%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_labels PASSED [ 72%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_imbalanced_labels PASSED [ 73%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_complete_metrics PASSED [ 74%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_zero_loss PASSED [ 75%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_all_metrics_are_floats PASSED [ 76%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_empty_labels PASSED [ 77%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 77%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 78%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 79%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [ 80%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_basic PASSED [ 81%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_with_indices PASSED [ 81%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_use_all_data PASSED [ 82%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_deberta_batch_size_cap PASSED [ 83%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_val_split_fallback PASSED [ 84%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_defaults PASSED [ 85%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_custom PASSED [ 86%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_warmup_capped PASSED [ 86%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_basic PASSED [ 87%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_multiple_epochs PASSED [ 88%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_success PASSED [ 89%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_creates_directory PASSED [ 90%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_basic PASSED [ 90%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_with_fold_splits PASSED [ 91%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_use_all_data PASSED [ 92%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx PASSED [ 93%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 94%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 95%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [ 95%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_value PASSED [ 96%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_none PASSED [ 97%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_zero PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_negative PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_multiple_calls PASSED [100%]
#
# ====================== 122 passed, 4 warnings in 11.38s =======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests\\unit\\training', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 122 items\n\ntests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override \x1bPASSED\x1b\x1b [  6%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override \x1bPASSED\x1b\x1b [  7%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true \x1bPASSED\x1b\x1b [  8%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false \x1bPASSED\x1b\x1b [  9%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override \x1bPASSED\x1b\x1b [  9%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override \x1bPASSED\x1b\x1b [ 10%]\x1b\ntests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides \x1bPASSED\x1b\x1b [ 11%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 \x1bPASSED\x1b\x1b [ 12%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 \x1bPASSED\x1b\x1b [ 13%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap \x1bPASSED\x1b\x1b [ 13%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used \x1bPASSED\x1b\x1b [ 14%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size \x1bPASSED\x1b\x1b [ 15%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility \x1bPASSED\x1b\x1b [ 16%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits \x1bPASSED\x1b\x1b [ 17%]\x1b\ntests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle \x1bPASSED\x1b\x1b [ 18%]\x1b\ntests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction \x1bPASSED\x1b\x1b [ 18%]\x1b\ntests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match \x1bPASSED\x1b\x1b [ 19%]\x1b\ntests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_i ...

# %% [markdown]
# ### Orchestration Tests
#
# Tests for pipeline orchestration: configuration loading, data asset management, and job creation.

# %%
run_tests("tests/unit/orchestration/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 149 items
#
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  0%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  1%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [  2%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [  2%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [  3%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [ 10%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [ 10%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [ 11%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [ 12%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [ 12%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [ 13%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_extract_best_config PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_empty_study_raises_error PASSED [ 15%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_excludes_backbone_from_params PASSED [ 16%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_includes_cv_statistics PASSED [ 16%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize PASSED [ 17%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_minimize PASSED [ 18%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_no_valid_trials_raises_error PASSED [ 18%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_choice_distribution PASSED [ 19%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_uniform_distribution PASSED [ 20%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_loguniform_distribution PASSED [ 20%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_multiple_parameters PASSED [ 21%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_create_median_pruner PASSED [ 22%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_pruner PASSED [ 22%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_early_termination PASSED [ 23%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_success PASSED [ 24%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_failure PASSED [ 24%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_fallback_to_mlflow PASSED [ 25%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_no_metrics PASSED [ 26%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_missing_objective_metric PASSED [ 26%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_success PASSED [ 27%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_failed_job PASSED [ 28%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_canceled_job PASSED [ 28%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_streams_logs PASSED [ 29%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_returns_completed_job PASSED [ 30%]
# tests/unit/orchestration/jobs/test_selection.py::TestConfigureMlflow::test_configure_mlflow_sets_tracking_uri PASSED [ 30%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_success PASSED [ 31%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_empty PASSED [ 32%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_error_handling PASSED [ 32%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_success PASSED [ 33%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_empty PASSED [ 34%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_error_handling PASSED [ 34%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_maximize PASSED [ 35%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_minimize PASSED [ 36%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_no_completed_trials PASSED [ 36%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_missing_metric PASSED [ 37%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_choice PASSED [ 38%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_uniform PASSED [ 38%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_loguniform PASSED [ 39%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_multiple_params PASSED [ 40%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 40%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 41%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_hpo_overrides PASSED [ 42%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_defaults PASSED [ 42%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_custom_seed PASSED [ 43%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_empty_hyperparameters PASSED [ 44%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_missing_training_section PASSED [ 44%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_success PASSED [ 45%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_failed_job PASSED [ 46%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_canceled_job PASSED [ 46%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 47%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 48%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_success PASSED [ 48%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_script_not_found PASSED [ 49%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_command_args PASSED [ 50%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_uses_asset_reference PASSED [ 51%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_outputs_checkpoint PASSED [ 51%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config PASSED [ 52%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_missing_experiment_file PASSED [ 53%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_invalid_yaml_structure PASSED [ 53%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_experiment_name_override PASSED [ 54%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_default_experiment_name PASSED [ 55%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_all_configs_loaded PASSED [ 55%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_config_structure PASSED [ 56%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_deterministic_hashing PASSED [ 57%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_different_configs_different_hashes PASSED [ 57%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_hash_length PASSED [ 58%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_order_independent PASSED [ 59%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_nested_configs PASSED [ 59%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_all_configs_hashed PASSED [ 60%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_hash_values_are_strings PASSED [ 61%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_structure PASSED [ 61%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_values_are_strings PASSED [ 62%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_snapshot_configs PASSED [ 63%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_unchanged_configs PASSED [ 63%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_mutated_configs PASSED [ 64%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_multiple_mutations PASSED [ 65%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 65%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 66%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 67%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [ 67%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_local_path PASSED [ 68%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_default PASSED [ 69%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_absolute_path PASSED [ 69%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_non_string PASSED [ 70%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_list PASSED [ 71%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_existing_asset PASSED [ 71%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_local_path PASSED [ 72%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_datastore_uri PASSED [ 73%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_http_uri PASSED [ 73%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_path_resolution_error PASSED [ 74%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_datastore_path PASSED [ 75%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_local_path_match PASSED [ 75%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_new_asset_creation PASSED [ 76%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_race_condition PASSED [ 77%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_fallback_to_input PASSED [ 77%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_path_normalization_string_comparison PASSED [ 78%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_datastore_path PASSED [ 79%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_without_datastore_path PASSED [ 79%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_trailing_slash PASSED [ 80%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_extracts_relative_path PASSED [ 81%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_defaults PASSED [ 81%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_custom_settings PASSED [ 82%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_partial_settings PASSED [ 83%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_empty_env_section PASSED [ 83%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_none_env_section PASSED [ 84%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_success PASSED [ 85%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_file_not_found PASSED [ 85%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_deterministic PASSED [ 86%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_inputs PASSED [ 87%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_docker_images PASSED [ 87%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_includes_both_inputs PASSED [ 88%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_get_existing_environment PASSED [ 89%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_create_new_environment PASSED [ 89%]
# tests/unit/orchestration/test_environment.py::TestCreateTrainingEnvironment::test_create_training_environment_success PASSED [ 90%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_existing_completed_job PASSED [ 91%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_no_matching_job PASSED [ 91%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_warmup_failed PASSED [ 92%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_list_jobs_failure PASSED [ 93%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_respects_history_limit PASSED [ 93%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_existing_stage PASSED [ 94%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_missing_stage PASSED [ 95%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_empty_config PASSED [ 95%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_none_config PASSED [ 96%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_backbone PASSED [ 97%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_without_backbone PASSED [ 97%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_different_stages PASSED [ 98%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_special_characters PASSED [ 99%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_empty_strings PASSED [100%]
#
# ====================== 149 passed, 472 warnings in 6.73s ======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests\\unit\\orchestration', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 149 items\n\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided \x1bPASSED\x1b\x1b [  6%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success \x1bPASSED\x1b\x1b [  6%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found \x1bPASSED\x1b\x1b [  7%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri \x1bPASSED\x1b\x1b [  8%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri \x1bPASSED\x1b\x1b [  8%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args \x1bPASSED\x1b\x1b [  9%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags \x1bPASSED\x1b\x1b [ 10%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success \x1bPASSED\x1b\x1b [ 10%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job \x1bPASSED\x1b\x1b [ 11% ...

# %% [markdown]
# ### Platform Adapter Tests
#
# Tests for platform-specific adapters (Azure ML vs Local): logging, output paths, and MLflow context management.

# %%
run_tests("tests/unit/platform_adapters/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 54 items
#
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter PASSED [  1%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter PASSED [  3%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir PASSED [  5%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job PASSED [  7%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job PASSED [  9%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver PASSED [ 11%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter PASSED [ 12%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job PASSED [ 14%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver PASSED [ 16%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter PASSED [ 18%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir PASSED [ 20%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 22%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 24%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt PASSED [ 25%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 27%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 29%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config PASSED [ 31%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file PASSED [ 33%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success PASSED [ 35%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit PASSED [ 37%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_nonexistent_path PASSED [ 38%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_traversal_error PASSED [ 40%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 42%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 44%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 46%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_success PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_nonexistent_path PASSED [ 53%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_traversal_error PASSED [ 55%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_with_azureml PASSED [ 57%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_without_azureml PASSED [ 59%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_with_azureml PASSED [ 61%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_without_azureml PASSED [ 62%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_metrics PASSED [ 64%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_params PASSED [ 66%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 68%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 70%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 72%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 74%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 75%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [ 77%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_named_output PASSED [ 79%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_generic PASSED [ 81%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_default PASSED [ 83%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_current_dir PASSED [ 85%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory PASSED [ 87%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory_existing PASSED [ 88%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_default PASSED [ 90%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_provided_default PASSED [ 92%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_no_default PASSED [ 94%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory PASSED [ 96%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_existing PASSED [ 98%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_nested PASSED [100%]
#
# ======================= 54 passed, 2 warnings in 2.23s ========================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests\\unit\\platform_adapters', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 54 items\n\ntests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job \x1bPASSED\x1b\x1b [  7%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job \x1bPASSED\x1b\x1b [  9%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver \x1bPASSED\x1b\x1b [ 11%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter \x1bPASSED\x1b\x1b [ 12%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job \x1bPASSED\x1b\x1b [ 14%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver \x1bPASSED\x1b\x1b [ 16%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter \x1bPASSED\x1b\x1b [ 18%]\x1b\ntests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir \x1bPASSED\x1b\x1b [ 20%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path \x1bPASSED\x1b\x1b [ 22%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path \x1bPASSED\x1b\x1b [ 24%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt \x1bPASSED\x1b\x1b [ 25%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found \x1bPASSED\x1b\x1b [ 27%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint \x1bPASSED\x1b\x1b [ 29%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config \x1bPASSED\x1b\x1b [ 31%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file \x1bPASSED\x1b\x1b [ 33%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success \x1bPASSED\x1b\x1b [ 35%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit \x1bPASSED\x1b\x1b [ 37%]\x1b\ntests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_ ...

# %% [markdown]
# ### Shared Utilities Tests
#
# Tests for shared utilities: YAML loading, JSON caching, and other common functionality.

# %%
run_tests("tests/unit/shared/", "-v", "--tb=short")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 15 items
#
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict PASSED [  6%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict PASSED [ 13%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory PASSED [ 20%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing PASSED [ 26%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file PASSED [ 33%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file PASSED [ 40%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default PASSED [ 46%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json PASSED [ 53%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file PASSED [ 60%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml PASSED [ 66%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml PASSED [ 73%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found PASSED [ 80%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml PASSED [ 86%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml PASSED [ 93%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments PASSED [100%]
#
# ============================= 15 passed in 0.10s ==============================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests\\unit\\shared', '-v', '--tb=short'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 15 items\n\ntests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict \x1bPASSED\x1b\x1b [  6%]\x1b\ntests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict \x1bPASSED\x1b\x1b [ 13%]\x1b\ntests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory \x1bPASSED\x1b\x1b [ 20%]\x1b\ntests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing \x1bPASSED\x1b\x1b [ 26%]\x1b\ntests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file \x1bPASSED\x1b\x1b [ 33%]\x1b\ntests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file \x1bPASSED\x1b\x1b [ 40%]\x1b\ntests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default \x1bPASSED\x1b\x1b [ 46%]\x1b\ntests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json \x1bPASSED\x1b\x1b [ 53%]\x1b\ntests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file \x1bPASSED\x1b\x1b [ 60%]\x1b\ntests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml \x1bPASSED\x1b\x1b [ 66%]\x1b\ntests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml \x1bPASSED\x1b\x1b [ 73%]\x1b\ntests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found \x1bPASSED\x1b\x1b [ 80%]\x1b\ntests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml \x1bPASSED\x1b\x1b [ 86%]\x1b\ntests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml \x1bPASSED\x1b\x1b [ 93%]\x1b\ntests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments \x1bPASSED\x1b\x1b [100%]\x1b\n\n\x1b============================= \x1b\x1b15 passed\x1b\x1b in 0.10s\x1b\x1b ==============================\x1b\n', stderr='')

# %% [markdown]
# ### YAML Test Configuration
#
# The test suite uses YAML configuration files in `config/test/` for:
# - Coverage thresholds (enforced automatically)
# - Test fixtures and mock settings
# - Environment-specific settings
#
# See `tests/README_YAML_CONFIG.md` for details.

# %% [markdown]
# ## Step 4: Generate Coverage Reports
#
# Generate code coverage reports to identify untested code paths.

# %%
run_tests("tests/", "--cov=src", "--cov-report=term-missing", "--cov-report=term:skip-covered")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 375 items
#
# tests/integration/test_train.py::TestParseArguments::test_parse_required_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_all_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_use_all_data PASSED [  0%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none PASSED [  1%]
# tests/integration/test_train.py::TestMain::test_main_success PASSED      [  1%]
# tests/integration/test_train.py::TestMain::test_main_config_dir_not_found PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_with_overrides PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_uses_platform_adapter PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [ 10%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_extract_best_config PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_empty_study_raises_error PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_excludes_backbone_from_params PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_includes_cv_statistics PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_minimize PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_no_valid_trials_raises_error PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_choice_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_uniform_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_loguniform_distribution PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_multiple_parameters PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_create_median_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_early_termination PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_success PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_failure PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_fallback_to_mlflow PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_no_metrics PASSED [ 15%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_missing_objective_metric PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_success PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_failed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_canceled_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_streams_logs PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_returns_completed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_selection.py::TestConfigureMlflow::test_configure_mlflow_sets_tracking_uri PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_success PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_empty PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_error_handling PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_success PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_empty PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_error_handling PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_maximize PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_minimize PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_no_completed_trials PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_missing_metric PASSED [ 19%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_choice PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_uniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_loguniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_multiple_params PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 21%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_hpo_overrides PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_defaults PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_custom_seed PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_empty_hyperparameters PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_missing_training_section PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_success PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_failed_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_canceled_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_success PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_script_not_found PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_command_args PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_uses_asset_reference PASSED [ 25%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_outputs_checkpoint PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_missing_experiment_file PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_invalid_yaml_structure PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_experiment_name_override PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_default_experiment_name PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_all_configs_loaded PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_config_structure PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_deterministic_hashing PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_different_configs_different_hashes PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_hash_length PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_order_independent PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_nested_configs PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_all_configs_hashed PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_hash_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_structure PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_snapshot_configs PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_unchanged_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_mutated_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_multiple_mutations PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_local_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_default PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_absolute_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_non_string PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_list PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_existing_asset PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_local_path PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_datastore_uri PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_http_uri PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_path_resolution_error PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_datastore_path PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_local_path_match PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_new_asset_creation PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_race_condition PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_fallback_to_input PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_path_normalization_string_comparison PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_without_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_trailing_slash PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_extracts_relative_path PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_defaults PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_custom_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_partial_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_empty_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_none_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_success PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_file_not_found PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_deterministic PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_inputs PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_docker_images PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_includes_both_inputs PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_get_existing_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_create_new_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestCreateTrainingEnvironment::test_create_training_environment_success PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_existing_completed_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_no_matching_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_warmup_failed PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_list_jobs_failure PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_respects_history_limit PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_existing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_missing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_empty_config PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_none_config PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_without_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_different_stages PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_special_characters PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_empty_strings PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter PASSED [ 47%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_nonexistent_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_traversal_error PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_success PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_nonexistent_path PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_traversal_error PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_with_azureml PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_with_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_metrics PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_params PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_named_output PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_generic PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_default PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_current_dir PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory_existing PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_provided_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_no_default PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_existing PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_nested PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json PASSED [ 61%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_required_arguments PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_optional_flags PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_success PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_failure PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_2d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_1d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_mixed_tensors PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_fp32 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_int8 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_export_failure PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_quantization_fallback PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_success PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_import_error PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_no_output PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_success PASSED   [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_with_smoke_test PASSED [ 67%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_config_dir_not_found PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file PASSED [ 68%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_val_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_round_trip_serialization PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_metadata_preserved PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_no_metadata PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_file_not_found PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_invalid_file_format PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_multiple_folds PASSED [ 76%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_directory_creation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_train_only PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_with_validation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_dataset_path PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_train_file PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_invalid_json PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_string_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_list_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_tuple_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_nested_list PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_dict_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_none_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_number_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_empty_list PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_perfect_alignment PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_no_annotations PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_partial_overlap PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_multiple_annotations_per_token PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_annotation_beyond_text PASSED [ 81%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_token_beyond_annotation PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_standard_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_empty_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_sorted_order PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_len PASSED  [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_fast_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_no_annotations PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_truncation PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_basic PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_with_mask PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_multiple_samples PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_unknown_label_id PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_empty_after_mask PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_success PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_multiple_batches PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_zero_loss PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_empty_dataloader PASSED [ 86%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_uses_no_grad PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_file PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_directory PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_calls_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_default_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_empty_dict PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_nested_values PASSED [ 88%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_overwrites_existing_file PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_perfect_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_no_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_partial_match PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_empty_lists PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_label_not_present PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_positives PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_negatives PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_multiple_labels PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_single_label PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_predictions PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_imbalanced_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_complete_metrics PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_zero_loss PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_all_metrics_are_floats PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_empty_labels PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_basic PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_with_indices PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_use_all_data PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_deberta_batch_size_cap PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_val_split_fallback PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_defaults PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_custom PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_warmup_capped PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_basic PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_multiple_epochs PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_success PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_creates_directory PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_basic PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_with_fold_splits PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_use_all_data PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx PASSED [ 97%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_value PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_none PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_zero PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_negative PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_multiple_calls PASSED [100%]
#
# =============================== tests coverage ================================
# ______________ coverage: platform win32, python 3.10.19-final-0 _______________
#
# Name                                           Stmts   Miss  Cover   Missing
# ----------------------------------------------------------------------------
# src\convert_to_onnx.py                           114      1    99%   275
# src\orchestration\environment.py                  68      1    99%   230
# src\orchestration\jobs\conversion.py              64      4    94%   47-48, 109-110
# src\orchestration\jobs\local_selection.py         59      6    90%   10-14, 134
# src\orchestration\jobs\local_sweeps.py           159     73    54%   21-28, 63, 91, 101, 150, 154, 165, 167, 215-219, 242-244, 279-300, 331-412, 442-494
# src\orchestration\jobs\selection.py               85     39    54%   14-15, 88-90, 114-168
# src\orchestration\jobs\sweeps.py                  73     49    33%   104-143, 199-250, 283-284, 299-310, 335-346
# src\platform_adapters\adapters.py                 60      9    85%   25, 30, 35, 40, 45, 68-69, 100-101
# src\platform_adapters\checkpoint_resolver.py      59      1    98%   25
# src\platform_adapters\logging_adapter.py          41      2    95%   18, 28
# src\platform_adapters\mlflow_context.py           19      1    95%   19
# src\platform_adapters\outputs.py                  39      2    95%   24, 37
# src\train.py                                      50      1    98%   163
# src\training\config.py                            40      3    92%   76, 78, 80
# src\training\data.py                              71      2    97%   77-78
# ----------------------------------------------------------------------------
# TOTAL                                           1437    194    86%
#
# 21 files skipped due to complete coverage.
# ===================== 375 passed, 478 warnings in 27.95s ======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests', '--cov=src', '--cov-report=term-missing', '--cov-report=term:skip-covered'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 375 items\n\ntests/integration/test_train.py::TestParseArguments::test_parse_required_arguments \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_all_arguments \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_use_all_data \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestMain::test_main_success \x1bPASSED\x1b\x1b      [  1%]\x1b\ntests/integration/test_train.py::TestMain::test_main_config_dir_not_found \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_train.py::TestMain::test_main_with_overrides \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_train.py::TestMain::test_main_uses_platform_adapter \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available \x1bPASSED\x1b\x1b  ...

# %%
result = run_tests("tests/", "--cov=src", "--cov-report=html", "--cov-report=term")

HTMLCOV_PATH = ROOT_DIR / "htmlcov" / "index.html"
COVERAGE_JSON = ROOT_DIR / ".coverage"

if HTMLCOV_PATH.exists():
    print(f"\n✓ HTML coverage report generated: {HTMLCOV_PATH}")
    print(f"  Coverage threshold: 80% (from config/test/execution.yaml)")
elif result.returncode != 0:
    print("\n✗ Coverage report not generated due to test failures.")
else:
    print("\n⚠ Coverage report not found. Check if pytest-cov is installed.")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 375 items
#
# tests/integration/test_train.py::TestParseArguments::test_parse_required_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_all_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_use_all_data PASSED [  0%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none PASSED [  1%]
# tests/integration/test_train.py::TestMain::test_main_success PASSED      [  1%]
# tests/integration/test_train.py::TestMain::test_main_config_dir_not_found PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_with_overrides PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_uses_platform_adapter PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [ 10%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_extract_best_config PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_empty_study_raises_error PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_excludes_backbone_from_params PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_includes_cv_statistics PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_minimize PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_no_valid_trials_raises_error PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_choice_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_uniform_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_loguniform_distribution PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_multiple_parameters PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_create_median_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_early_termination PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_success PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_failure PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_fallback_to_mlflow PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_no_metrics PASSED [ 15%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_missing_objective_metric PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_success PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_failed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_canceled_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_streams_logs PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_returns_completed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_selection.py::TestConfigureMlflow::test_configure_mlflow_sets_tracking_uri PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_success PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_empty PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_error_handling PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_success PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_empty PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_error_handling PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_maximize PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_minimize PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_no_completed_trials PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_missing_metric PASSED [ 19%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_choice PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_uniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_loguniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_multiple_params PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 21%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_hpo_overrides PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_defaults PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_custom_seed PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_empty_hyperparameters PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_missing_training_section PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_success PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_failed_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_canceled_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_success PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_script_not_found PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_command_args PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_uses_asset_reference PASSED [ 25%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_outputs_checkpoint PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_missing_experiment_file PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_invalid_yaml_structure PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_experiment_name_override PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_default_experiment_name PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_all_configs_loaded PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_config_structure PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_deterministic_hashing PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_different_configs_different_hashes PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_hash_length PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_order_independent PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_nested_configs PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_all_configs_hashed PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_hash_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_structure PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_snapshot_configs PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_unchanged_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_mutated_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_multiple_mutations PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_local_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_default PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_absolute_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_non_string PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_list PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_existing_asset PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_local_path PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_datastore_uri PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_http_uri PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_path_resolution_error PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_datastore_path PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_local_path_match PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_new_asset_creation PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_race_condition PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_fallback_to_input PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_path_normalization_string_comparison PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_without_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_trailing_slash PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_extracts_relative_path PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_defaults PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_custom_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_partial_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_empty_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_none_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_success PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_file_not_found PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_deterministic PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_inputs PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_docker_images PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_includes_both_inputs PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_get_existing_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_create_new_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestCreateTrainingEnvironment::test_create_training_environment_success PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_existing_completed_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_no_matching_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_warmup_failed PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_list_jobs_failure PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_respects_history_limit PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_existing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_missing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_empty_config PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_none_config PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_without_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_different_stages PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_special_characters PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_empty_strings PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter PASSED [ 47%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_nonexistent_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_traversal_error PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_success PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_nonexistent_path PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_traversal_error PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_with_azureml PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_with_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_metrics PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_params PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_named_output PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_generic PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_default PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_current_dir PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory_existing PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_provided_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_no_default PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_existing PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_nested PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json PASSED [ 61%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_required_arguments PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_optional_flags PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_success PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_failure PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_2d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_1d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_mixed_tensors PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_fp32 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_int8 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_export_failure PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_quantization_fallback PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_success PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_import_error PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_no_output PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_success PASSED   [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_with_smoke_test PASSED [ 67%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_config_dir_not_found PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file PASSED [ 68%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_val_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_round_trip_serialization PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_metadata_preserved PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_no_metadata PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_file_not_found PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_invalid_file_format PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_multiple_folds PASSED [ 76%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_directory_creation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_train_only PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_with_validation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_dataset_path PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_train_file PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_invalid_json PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_string_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_list_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_tuple_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_nested_list PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_dict_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_none_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_number_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_empty_list PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_perfect_alignment PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_no_annotations PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_partial_overlap PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_multiple_annotations_per_token PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_annotation_beyond_text PASSED [ 81%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_token_beyond_annotation PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_standard_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_empty_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_sorted_order PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_len PASSED  [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_fast_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_no_annotations PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_truncation PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_basic PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_with_mask PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_multiple_samples PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_unknown_label_id PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_empty_after_mask PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_success PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_multiple_batches PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_zero_loss PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_empty_dataloader PASSED [ 86%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_uses_no_grad PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_file PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_directory PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_calls_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_default_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_empty_dict PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_nested_values PASSED [ 88%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_overwrites_existing_file PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_perfect_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_no_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_partial_match PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_empty_lists PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_label_not_present PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_positives PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_negatives PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_multiple_labels PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_single_label PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_predictions PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_imbalanced_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_complete_metrics PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_zero_loss PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_all_metrics_are_floats PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_empty_labels PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_basic PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_with_indices PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_use_all_data PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_deberta_batch_size_cap PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_val_split_fallback PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_defaults PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_custom PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_warmup_capped PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_basic PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_multiple_epochs PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_success PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_creates_directory PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_basic PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_with_fold_splits PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_use_all_data PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx PASSED [ 97%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_value PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_none PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_zero PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_negative PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_multiple_calls PASSED [100%]
#
# =============================== tests coverage ================================
# ______________ coverage: platform win32, python 3.10.19-final-0 _______________
#
# Name                                           Stmts   Miss  Cover
# ------------------------------------------------------------------
# src\__init__.py                                    0      0   100%
# src\convert_to_onnx.py                           114      1    99%
# src\orchestration\__init__.py                      3      0   100%
# src\orchestration\config_loader.py                43      0   100%
# src\orchestration\constants.py                     7      0   100%
# src\orchestration\data_assets.py                  56      0   100%
# src\orchestration\environment.py                  68      1    99%
# src\orchestration\jobs\__init__.py                 9      0   100%
# src\orchestration\jobs\conversion.py              64      4    94%
# src\orchestration\jobs\local_selection.py         59      6    90%
# src\orchestration\jobs\local_sweeps.py           159     73    54%
# src\orchestration\jobs\runtime.py                 11      0   100%
# src\orchestration\jobs\selection.py               85     39    54%
# src\orchestration\jobs\sweeps.py                  73     49    33%
# src\orchestration\jobs\training.py                21      0   100%
# src\orchestration\naming.py                       10      0   100%
# src\platform_adapters\__init__.py                  6      0   100%
# src\platform_adapters\adapters.py                 60      9    85%
# src\platform_adapters\checkpoint_resolver.py      59      1    98%
# src\platform_adapters\logging_adapter.py          41      2    95%
# src\platform_adapters\mlflow_context.py           19      1    95%
# src\platform_adapters\outputs.py                  39      2    95%
# src\shared\__init__.py                             0      0   100%
# src\shared\json_cache.py                          15      0   100%
# src\shared\yaml_utils.py                           9      0   100%
# src\train.py                                      50      1    98%
# src\training\__init__.py                           9      0   100%
# src\training\config.py                            40      3    92%
# src\training\cv_utils.py                          39      0   100%
# src\training\data.py                              71      2    97%
# src\training\evaluator.py                         39      0   100%
# src\training\logging.py                           14      0   100%
# src\training\metrics.py                           30      0   100%
# src\training\model.py                             12      0   100%
# src\training\trainer.py                           96      0   100%
# src\training\utils.py                              7      0   100%
# ------------------------------------------------------------------
# TOTAL                                           1437    194    86%
# Coverage HTML written to dir htmlcov
# ===================== 375 passed, 478 warnings in 29.52s ======================
#
#
# ✓ All tests passed
#
# ✓ HTML coverage report generated: c:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml\htmlcov\index.html
#   Coverage threshold: 80% (from config/test/execution.yaml)

# %% [markdown]
# ### Test Statistics
#
# Counts test files by category and provides overview of test suite structure.

# %%
import webbrowser
from IPython.display import HTML

if 'HTMLCOV_PATH' not in globals():
    HTMLCOV_PATH = ROOT_DIR / "htmlcov" / "index.html"

if HTMLCOV_PATH.exists():
    file_uri = HTMLCOV_PATH.absolute().as_uri()
    webbrowser.open(file_uri)
    display(HTML(f'Coverage report opened in browser. File: <code>{HTMLCOV_PATH}</code>'))
else:
    print("Coverage report not found. Run the coverage generation cell above first.")
# Out:
# Coverage report opened in browser. File: <code>c:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml\htmlcov\index.html</code>

# %% [markdown]
# ### Coverage Summary
#
# Displays coverage thresholds from YAML configuration. For detailed coverage breakdown, open the HTML report in your browser.

# %% [markdown]
# ## Step 5: Run Troubleshooting Prevention Tests
#
# Run tests that verify fixes for common issues documented in TROUBLESHOOTING.md.

# %%
TROUBLESHOOTING_TESTS = [
    "tests/unit/training/test_trainer_oom_prevention.py",
    "tests/unit/orchestration/test_data_asset_references.py",
    "tests/unit/platform_adapters/test_mlflow_context.py",
    "tests/unit/training/test_tokenizer_offset_mapping.py",
    "tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py",
    "tests/integration/test_troubleshooting_fixes.py",
]

for test_file in TROUBLESHOOTING_TESTS:
    test_path = ROOT_DIR / test_file
    if test_path.exists():
        print(f"\nRunning: {test_file}")
        run_tests(test_file, "-v", "--tb=short")
    else:
        print(f"⚠ Test file not found: {test_file}")
# Out:
# Running: tests/unit/training/test_trainer_oom_prevention.py
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 3 items
#
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 33%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 66%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [100%]
#
# ============================== 3 passed in 8.82s ==============================
#
#
# ✓ All tests passed
#
# Running: tests/unit/orchestration/test_data_asset_references.py
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 4 items
#
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 25%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 50%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 75%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [100%]
#
# ======================= 4 passed, 470 warnings in 6.16s =======================
#
#
# ✓ All tests passed
#
# Running: tests/unit/platform_adapters/test_mlflow_context.py
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 6 items
#
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 16%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 33%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 50%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 66%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 83%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [100%]
#
# ============================== 6 passed in 0.06s ==============================
#
#
# ✓ All tests passed
#
# Running: tests/unit/training/test_tokenizer_offset_mapping.py
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 4 items
#
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 25%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 50%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 75%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [100%]
#
# ============================== 4 passed in 8.46s ==============================
#
#
# ✓ All tests passed
#
# Running: tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 21 items
#
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [ 14%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [ 19%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [ 23%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [ 28%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [ 33%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [ 38%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [ 42%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [ 47%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [ 52%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [ 57%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [ 61%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [ 66%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [ 71%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [ 76%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [ 80%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [ 85%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [ 90%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [ 95%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [100%]
#
# ====================== 21 passed, 472 warnings in 6.91s =======================
#
#
# ✓ All tests passed
#
# Running: tests/integration/test_troubleshooting_fixes.py
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 8 items
#
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root PASSED [ 12%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error PASSED [ 25%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference PASSED [ 37%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference PASSED [ 50%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run PASSED [ 62%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run PASSED [ 75%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories PASSED [ 87%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files PASSED [100%]
#
# ====================== 8 passed, 470 warnings in 14.51s =======================
#
#
# ✓ All tests passed

# %% [markdown]
# ## Step 6: Explore Test Results
#
# Analyze test results and explore specific test scenarios.

# %%
run_tests("tests/", "-v", "--durations=10", "--tb=long")
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\Users\HOANG PHI LONG DANG\Miniconda3\envs\resume-ner-training\python.exe
# cachedir: .pytest_cache
# YAML Test Configuration: Loaded from config/test/
#   Overall Coverage Threshold: 80%
#   Module Thresholds:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%
# rootdir: C:\Users\HOANG PHI LONG DANG\repos\resume-ner-azureml
# configfile: pytest.ini
# plugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1
# collecting ... collected 375 items
#
# tests/integration/test_train.py::TestParseArguments::test_parse_required_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_all_arguments PASSED [  0%]
# tests/integration/test_train.py::TestParseArguments::test_parse_use_all_data PASSED [  0%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params PASSED [  1%]
# tests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none PASSED [  1%]
# tests/integration/test_train.py::TestMain::test_main_success PASSED      [  1%]
# tests/integration/test_train.py::TestMain::test_main_config_dir_not_found PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_with_overrides PASSED [  2%]
# tests/integration/test_train.py::TestMain::test_main_uses_platform_adapter PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root PASSED [  2%]
# tests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference PASSED [  3%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories PASSED [  4%]
# tests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files PASSED [  4%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_raises_error_if_job_not_completed PASSED [  5%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_asset_reference_not_datastore_path PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_returns_asset_uri_format PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_path_if_uri_not_available PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_fallback_to_asset_reference_when_no_outputs PASSED [  6%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetJobOutputReference::test_uses_ml_client_when_provided PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_success PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_script_not_found PASSED [  7%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_invalid_checkpoint_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_with_datastore_uri PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_command_args PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestCreateConversionJob::test_create_conversion_job_empty_tags PASSED [  8%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_success PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_failed_job PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_no_outputs PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_missing_onnx_output PASSED [  9%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_invalid_output_reference PASSED [ 10%]
# tests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestValidateConversionJob::test_validate_uses_ml_client PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_extract_best_config PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_empty_study_raises_error PASSED [ 10%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_excludes_backbone_from_params PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestExtractBestConfigFromStudy::test_includes_cv_statistics PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize PASSED [ 11%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_minimize PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_no_valid_trials_raises_error PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_choice_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_uniform_distribution PASSED [ 12%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_loguniform_distribution PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestTranslateSearchSpaceToOptuna::test_multiple_parameters PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_create_median_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_pruner PASSED [ 13%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestCreateOptunaPruner::test_no_early_termination PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_success PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_failure PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_fallback_to_mlflow PASSED [ 14%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_no_metrics PASSED [ 15%]
# tests/unit/orchestration/jobs/test_local_sweeps.py::TestRunTrainingTrial::test_run_training_trial_missing_objective_metric PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_success PASSED [ 15%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_failed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_canceled_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_streams_logs PASSED [ 16%]
# tests/unit/orchestration/jobs/test_runtime.py::TestSubmitAndWaitForJob::test_submit_and_wait_returns_completed_job PASSED [ 16%]
# tests/unit/orchestration/jobs/test_selection.py::TestConfigureMlflow::test_configure_mlflow_sets_tracking_uri PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_success PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_empty PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetMetricsFromMlflow::test_get_metrics_error_handling PASSED [ 17%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_success PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_empty PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetParamsFromMlflow::test_get_params_error_handling PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_maximize PASSED [ 18%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_minimize PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_no_completed_trials PASSED [ 19%]
# tests/unit/orchestration/jobs/test_selection.py::TestGetBestTrialFromSweep::test_get_best_trial_missing_metric PASSED [ 19%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_choice PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_uniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_loguniform PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestCreateSearchSpace::test_create_search_space_multiple_params PASSED [ 20%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 21%]
# tests/unit/orchestration/jobs/test_sweeps.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_hpo_overrides PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_defaults PASSED [ 21%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_custom_seed PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_empty_hyperparameters PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildFinalTrainingConfig::test_build_config_with_missing_training_section PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_success PASSED [ 22%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_failed_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestValidateFinalTrainingJob::test_validate_canceled_job PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_uses_asset_reference PASSED [ 23%]
# tests/unit/orchestration/jobs/test_training.py::TestBuildDataInputFromAsset::test_build_input_not_datastore_path PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_success PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_script_not_found PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_command_args PASSED [ 24%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_uses_asset_reference PASSED [ 25%]
# tests/unit/orchestration/jobs/test_training.py::TestCreateFinalTrainingJob::test_create_job_outputs_checkpoint PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_missing_experiment_file PASSED [ 25%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_invalid_yaml_structure PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_experiment_name_override PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_default_experiment_name PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_all_configs_loaded PASSED [ 26%]
# tests/unit/orchestration/test_config_loader.py::TestLoadAllConfigs::test_config_structure PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_deterministic_hashing PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_different_configs_different_hashes PASSED [ 27%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_hash_length PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_order_independent PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHash::test_nested_configs PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_all_configs_hashed PASSED [ 28%]
# tests/unit/orchestration/test_config_loader.py::TestComputeConfigHashes::test_hash_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_structure PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestCreateConfigMetadata::test_metadata_values_are_strings PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_snapshot_configs PASSED [ 29%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_unchanged_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_mutated_configs PASSED [ 30%]
# tests/unit/orchestration/test_config_loader.py::TestSnapshotAndValidateConfigs::test_validate_multiple_mutations PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_asset_reference_format PASSED [ 30%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_sweeps_build_data_input_uses_asset_reference PASSED [ 31%]
# tests/unit/orchestration/test_data_asset_references.py::TestDataAssetReferenceFormat::test_asset_reference_not_manual_datastore_path PASSED [ 31%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_local_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_default PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_with_absolute_path PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_non_string PASSED [ 32%]
# tests/unit/orchestration/test_data_assets.py::TestResolveDatasetPath::test_resolve_raises_error_for_list PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_existing_asset PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_local_path PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_datastore_uri PASSED [ 33%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_http_uri PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestRegisterDataAsset::test_register_new_asset_path_resolution_error PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_datastore_path PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_existing_asset_local_path_match PASSED [ 34%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_new_asset_creation PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_race_condition PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_creation_fallback_to_input PASSED [ 35%]
# tests/unit/orchestration/test_data_assets.py::TestEnsureDataAssetUploaded::test_ensure_asset_path_normalization_string_comparison PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_without_datastore_path PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_with_trailing_slash PASSED [ 36%]
# tests/unit/orchestration/test_data_assets.py::TestBuildDataAssetReference::test_build_reference_extracts_relative_path PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_defaults PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_custom_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_partial_settings PASSED [ 37%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_empty_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestBuildEnvironmentConfig::test_build_with_none_env_section PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_success PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestLoadCondaEnvironment::test_load_conda_environment_file_not_found PASSED [ 38%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_deterministic PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_inputs PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_different_docker_images PASSED [ 39%]
# tests/unit/orchestration/test_environment.py::TestComputeEnvironmentHash::test_compute_hash_includes_both_inputs PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_get_existing_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestGetOrCreateEnvironment::test_create_new_environment PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestCreateTrainingEnvironment::test_create_training_environment_success PASSED [ 40%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_existing_completed_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_no_matching_job PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_warmup_failed PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_list_jobs_failure PASSED [ 41%]
# tests/unit/orchestration/test_environment.py::TestPrepareEnvironmentImage::test_prepare_environment_image_respects_history_limit PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_existing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_missing_stage PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_empty_config PASSED [ 42%]
# tests/unit/orchestration/test_naming.py::TestGetStageConfig::test_get_stage_with_none_config PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_without_backbone PASSED [ 43%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_different_stages PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_with_special_characters PASSED [ 44%]
# tests/unit/orchestration/test_naming.py::TestBuildAmlExperimentName::test_build_name_empty_strings PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_azureml_adapter PASSED [ 44%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_detect_local_adapter PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestGetPlatformAdapter::test_local_adapter_with_default_dir PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_is_not_platform_job PASSED [ 45%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_is_platform_job PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_output_path_resolver PASSED [ 46%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_get_logging_adapter PASSED [ 47%]
# tests/unit/platform_adapters/test_adapters.py::TestLocalAdapter::test_default_output_dir PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 47%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_model_pt PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 48%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_config PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_resolve_checkpoint_dir_missing_model_file PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_success PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit PASSED [ 49%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_nonexistent_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_traversal_error PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_direct_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_nested_path PASSED [ 50%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_path_not_found PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_resolve_checkpoint_dir_no_valid_checkpoint PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_success PASSED [ 51%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_nonexistent_path PASSED [ 52%]
# tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_traversal_error PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_with_azureml PASSED [ 52%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_metrics_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_with_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestAzureMLLoggingAdapter::test_log_params_without_azureml PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_metrics PASSED [ 53%]
# tests/unit/platform_adapters/test_logging_adapter.py::TestLocalLoggingAdapter::test_log_params PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_get_context_returns_nullcontext PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_does_not_start_new_run PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestAzureMLMLflowContextManager::test_context_is_no_op PASSED [ 54%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_get_context_starts_run PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_sets_experiment_from_env PASSED [ 55%]
# tests/unit/platform_adapters/test_mlflow_context.py::TestLocalMLflowContextManager::test_no_experiment_if_env_not_set PASSED [ 55%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_named_output PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_generic PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_default PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_resolve_fallback_to_current_dir PASSED [ 56%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestAzureMLOutputPathResolver::test_ensure_output_directory_existing PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_with_provided_default PASSED [ 57%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_resolve_output_path_no_default PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_existing PASSED [ 58%]
# tests/unit/platform_adapters/test_outputs.py::TestLocalOutputPathResolver::test_ensure_output_directory_nested PASSED [ 58%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_simple_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_save_nested_dict PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_create_parent_directory PASSED [ 59%]
# tests/unit/shared/test_json_cache.py::TestSaveJson::test_pretty_printing PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_existing_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_nonexistent_file_with_default PASSED [ 60%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_invalid_json PASSED [ 61%]
# tests/unit/shared/test_json_cache.py::TestLoadJson::test_load_empty_file PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_valid_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_load_nested_yaml PASSED [ 61%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_file_not_found PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_invalid_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_empty_yaml PASSED [ 62%]
# tests/unit/shared/test_yaml_utils.py::TestLoadYaml::test_yaml_with_comments PASSED [ 62%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_required_arguments PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestParseArguments::test_parse_optional_flags PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_success PASSED [ 63%]
# tests/unit/test_convert_to_onnx.py::TestResolveCheckpointDir::test_resolve_checkpoint_dir_failure PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_2d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_1d_tensor PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestDynamicAxesFor::test_dynamic_axes_mixed_tensors PASSED [ 64%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_fp32 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_int8 PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_export_failure PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_quantization_fallback PASSED [ 65%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_success PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_import_error PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestRunSmokeTest::test_run_smoke_test_no_output PASSED [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_success PASSED   [ 66%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_with_smoke_test PASSED [ 67%]
# tests/unit/test_convert_to_onnx.py::TestMain::test_main_config_dir_not_found PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_basic_config_loading PASSED [ 67%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_missing_config_file PASSED [ 68%]
# tests/unit/training/test_config.py::TestBuildTrainingConfig::test_config_structure PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_learning_rate_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_batch_size_override PASSED [ 68%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_dropout_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_weight_decay_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_epochs_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_random_seed_override PASSED [ 69%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_true PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_early_stopping_enabled_false PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_use_combined_data_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_fold_idx_override PASSED [ 70%]
# tests/unit/training/test_config.py::TestApplyArgumentOverrides::test_multiple_overrides PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_2 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_equals_5 PASSED [ 71%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_overlap PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_all_samples_used PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_k_greater_than_dataset_size PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_reproducibility PASSED [ 72%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_different_seeds_produce_different_splits PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestCreateKfoldSplits::test_no_shuffle PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_correct_data_extraction PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_indices_match PASSED [ 73%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_train_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestGetFoldData::test_empty_val_indices PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_round_trip_serialization PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_metadata_preserved PASSED [ 74%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_no_metadata PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_file_not_found PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_invalid_file_format PASSED [ 75%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_multiple_folds PASSED [ 76%]
# tests/unit/training/test_cv_utils.py::TestSaveAndLoadFoldSplits::test_directory_creation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_train_only PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_with_validation PASSED [ 76%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_dataset_path PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_missing_train_file PASSED [ 77%]
# tests/unit/training/test_data.py::TestLoadDataset::test_invalid_json PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_string_input PASSED [ 77%]
# tests/unit/training/test_data.py::TestNormalizeText::test_list_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_tuple_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_nested_list PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_dict_input PASSED [ 78%]
# tests/unit/training/test_data.py::TestNormalizeText::test_none_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_number_input PASSED [ 79%]
# tests/unit/training/test_data.py::TestNormalizeText::test_empty_list PASSED [ 79%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_perfect_alignment PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_no_annotations PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_partial_overlap PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_multiple_annotations_per_token PASSED [ 80%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_annotation_beyond_text PASSED [ 81%]
# tests/unit/training/test_data.py::TestEncodeAnnotationsToLabels::test_token_beyond_annotation PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_standard_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_empty_entity_types PASSED [ 81%]
# tests/unit/training/test_data.py::TestBuildLabelList::test_sorted_order PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_len PASSED  [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_fast_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer PASSED [ 82%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_no_annotations PASSED [ 83%]
# tests/unit/training/test_data.py::TestResumeNERDataset::test_truncation PASSED [ 83%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_basic PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_with_mask PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_multiple_samples PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_unknown_label_id PASSED [ 84%]
# tests/unit/training/test_evaluator.py::TestExtractPredictionsAndLabels::test_extract_predictions_and_labels_empty_after_mask PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_success PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_multiple_batches PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_zero_loss PASSED [ 85%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_empty_dataloader PASSED [ 86%]
# tests/unit/training/test_evaluator.py::TestEvaluateModel::test_evaluate_model_uses_no_grad PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_file PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_directory PASSED [ 86%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_calls_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_creates_default_adapter PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_empty_dict PASSED [ 87%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_with_nested_values PASSED [ 88%]
# tests/unit/training/test_logging.py::TestLogMetrics::test_log_metrics_overwrites_existing_file PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_perfect_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_no_match PASSED [ 88%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_partial_match PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_empty_lists PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_label_not_present PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_positives PASSED [ 89%]
# tests/unit/training/test_metrics.py::TestComputeF1ForLabel::test_only_false_negatives PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_multiple_labels PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_single_label PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_predictions PASSED [ 90%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_empty_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeTokenMacroF1::test_imbalanced_labels PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_complete_metrics PASSED [ 91%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_zero_loss PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_all_metrics_are_floats PASSED [ 92%]
# tests/unit/training/test_metrics.py::TestComputeMetrics::test_empty_labels PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_fast_tokenizer_uses_offset_mapping PASSED [ 92%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_slow_tokenizer_fallback_to_o_labels PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_tokenizer_offset_detection PASSED [ 93%]
# tests/unit/training/test_tokenizer_offset_mapping.py::TestTokenizerOffsetMappingHandling::test_no_notimplemented_error_with_slow_tokenizer PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_basic PASSED [ 93%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_with_indices PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_use_all_data PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_deberta_batch_size_cap PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestPrepareDataLoaders::test_prepare_data_loaders_val_split_fallback PASSED [ 94%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_defaults PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_custom PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestCreateOptimizerAndScheduler::test_create_optimizer_and_scheduler_warmup_capped PASSED [ 95%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_basic PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestRunTrainingLoop::test_run_training_loop_multiple_epochs PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_success PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestSaveCheckpoint::test_save_checkpoint_creates_directory PASSED [ 96%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_basic PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_with_fold_splits PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_use_all_data PASSED [ 97%]
# tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx PASSED [ 97%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_non_deberta_batch_size_not_capped PASSED [ 98%]
# tests/unit/training/test_trainer_oom_prevention.py::TestDeBERTaBatchSizeCapping::test_deberta_batch_size_below_limit_not_capped PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_value PASSED [ 98%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_none PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_zero PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_with_negative PASSED [ 99%]
# tests/unit/training/test_utils.py::TestSetSeed::test_set_seed_multiple_calls PASSED [100%]
#
# ============================ slowest 10 durations =============================
# 2.62s call     tests/unit/training/test_trainer.py::TestTrainModel::test_train_model_invalid_fold_idx
# 1.27s call     tests/unit/platform_adapters/test_adapters.py::TestAzureMLAdapter::test_get_logging_adapter
# 0.25s call     tests/unit/test_convert_to_onnx.py::TestConvertToOnnx::test_convert_to_onnx_int8
# 0.09s call     tests/unit/orchestration/jobs/test_local_selection.py::TestSelectBestConfigurationAcrossStudies::test_select_best_across_studies_maximize
# 0.06s call     tests/unit/platform_adapters/test_checkpoint_resolver.py::TestAzureMLCheckpointResolver::test_list_files_with_limit
# 0.05s call     tests/unit/platform_adapters/test_checkpoint_resolver.py::TestLocalCheckpointResolver::test_list_files_with_limit
# 0.03s setup    tests/unit/orchestration/test_config_loader.py::TestLoadExperimentConfig::test_valid_config
# 0.02s setup    tests/unit/training/test_data.py::TestResumeNERDataset::test_len
# 0.02s setup    tests/unit/training/test_data.py::TestResumeNERDataset::test_empty_text
# 0.02s setup    tests/unit/training/test_data.py::TestResumeNERDataset::test_getitem_slow_tokenizer
# ===================== 375 passed, 478 warnings in 22.12s ======================
#
#
# ✓ All tests passed
# CompletedProcess(args=['pytest', 'C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\\tests', '-v', '--durations=10', '--tb=long'], returncode=0, stdout='\x1b============================= test session starts =============================\x1b\nplatform win32 -- Python 3.10.19, pytest-9.0.2, pluggy-1.6.0 -- c:\\Users\\HOANG PHI LONG DANG\\Miniconda3\\envs\\resume-ner-training\\python.exe\ncachedir: .pytest_cache\nYAML Test Configuration: Loaded from config/test/\n  Overall Coverage Threshold: 80%\n  Module Thresholds:\n    - conversion: 80%\n    - convert_to_onnx: 70%\n    - data_assets: 80%\n    - environment: 70%\n    - local_sweeps: 75%\n    - logging: 80%\n    - naming: 80%\n    - orchestration: 75%\n    - platform_adapters: 90%\n    - runtime: 80%\n    - selection: 75%\n    - shared: 95%\n    - sweeps: 75%\n    - train: 70%\n    - training: 85%\n    - training_jobs: 80%\n    - utils: 80%\nrootdir: C:\\Users\\HOANG PHI LONG DANG\\repos\\resume-ner-azureml\nconfigfile: pytest.ini\nplugins: anyio-4.12.0, cov-7.0.0, mock-3.15.1\n\x1bcollecting ... \x1bcollected 375 items\n\ntests/integration/test_train.py::TestParseArguments::test_parse_required_arguments \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_all_arguments \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestParseArguments::test_parse_use_all_data \x1bPASSED\x1b\x1b [  0%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_all_params \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_partial_params \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestLogTrainingParameters::test_log_training_parameters_filters_none \x1bPASSED\x1b\x1b [  1%]\x1b\ntests/integration/test_train.py::TestMain::test_main_success \x1bPASSED\x1b\x1b      [  1%]\x1b\ntests/integration/test_train.py::TestMain::test_main_config_dir_not_found \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_train.py::TestMain::test_main_with_overrides \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_train.py::TestMain::test_main_uses_platform_adapter \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_relative_to_code_root \x1bPASSED\x1b\x1b [  2%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestConfigDirectoryResolution::test_config_dir_not_found_raises_error \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_training_job_uses_asset_reference \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestDataAssetReferenceFormat::test_sweep_job_uses_asset_reference \x1bPASSED\x1b\x1b [  3%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_azure_ml_does_not_create_nested_run \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestMLflowContextManagement::test_local_creates_mlflow_run \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_searches_nested_directories \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/integration/test_troubleshooting_fixes.py::TestCheckpointPathResolution::test_checkpoint_resolver_finds_hf_model_files \x1bPASSED\x1b\x1b [  4%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_asset_reference_format \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_fallback_to_direct_construction \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jobs/test_conversion_checkpoint_resolution.py::TestGetCheckpointOutputFromTrainingJob::test_uses_job_output_uri_if_available \x1bPASSED\x1b\x1b [  5%]\x1b\ntests/unit/orchestration/jo ...

# %% [markdown]
# ### Example Commands
#
# Uncomment and modify the examples below to run specific test scenarios.

# %%
# Example: Run a specific test file
# run_tests("tests/unit/training/test_metrics.py", "-v", "--tb=short")

# %%
# Example: Run tests matching a pattern
# run_tests("tests/", "-k", "tokenizer", "-v")

# %%
# Example: Run tests in parallel (requires pytest-xdist)
# run_tests("tests/", "-n", "auto", "-v")

# %% [markdown]
# ## Test Statistics and Summary
#
# Generate a summary of test statistics and coverage.

# %%
import json

def count_test_files(directory):
    return len(list(directory.glob("test_*.py")))

test_categories = {
    "unit/training": count_test_files(TESTS_DIR / "unit" / "training"),
    "unit/orchestration": count_test_files(TESTS_DIR / "unit" / "orchestration") + count_test_files(TESTS_DIR / "unit" / "orchestration" / "jobs"),
    "unit/platform_adapters": count_test_files(TESTS_DIR / "unit" / "platform_adapters"),
    "unit/shared": count_test_files(TESTS_DIR / "unit" / "shared"),
    "integration": count_test_files(TESTS_DIR / "integration"),
}

total_files = sum(test_categories.values())
print(f"Total test files: {total_files}")
for category, count in test_categories.items():
    print(f"  {category}: {count}")
# Out:
# Total test files: 31
#   unit/training: 10
#   unit/orchestration: 12
#   unit/platform_adapters: 5
#   unit/shared: 2
#   integration: 2

# %%
# Load coverage data from HTML report or JSON if available
try:
    from tests.config_loader import get_execution_settings, get_coverage_threshold
    
    execution_settings = get_execution_settings()
    coverage_config = execution_settings.get("coverage", {})
    overall_threshold = coverage_config.get("overall_threshold", 80)
    module_thresholds = coverage_config.get("module_thresholds", {})
    
    print(f"Coverage Thresholds (from config/test/execution.yaml):")
    print(f"  Overall: {overall_threshold}%")
    if module_thresholds:
        print(f"  Module-specific:")
        for module, threshold in sorted(module_thresholds.items()):
            print(f"    - {module}: {threshold}%")
except ImportError as e:
    print("⚠ YAML config loader not available. Using defaults.")
    print(f"  Error: {e}")
    print("  Overall threshold: 80%")

# Note: Detailed coverage breakdown is available in the HTML report
# Open htmlcov/index.html in your browser for full details
# Out:
# Coverage Thresholds (from config/test/execution.yaml):
#   Overall: 80%
#   Module-specific:
#     - conversion: 80%
#     - convert_to_onnx: 70%
#     - data_assets: 80%
#     - environment: 70%
#     - local_sweeps: 75%
#     - logging: 80%
#     - naming: 80%
#     - orchestration: 75%
#     - platform_adapters: 90%
#     - runtime: 80%
#     - selection: 75%
#     - shared: 95%
#     - sweeps: 75%
#     - train: 70%
#     - training: 85%
#     - training_jobs: 80%
#     - utils: 80%

# %% [markdown]
# ## Quick Reference
#
# ### Common Test Commands
#
# ```bash
# # Run all tests
# pytest tests/
#
# # Run with coverage (thresholds from config/test/execution.yaml)
# pytest tests/ --cov=src --cov-report=html
#
# # Run specific test file
# pytest tests/unit/training/test_metrics.py
#
# # Run tests matching pattern
# pytest tests/ -k "test_metrics"
#
# # Run in parallel
# pytest tests/ -n auto
#
# # Show slowest tests
# pytest tests/ --durations=10
# ```
#
# ### Test Categories
#
# - **Unit Tests**: Fast, isolated tests for individual components
# - **Integration Tests**: Tests for component interactions
# - **Troubleshooting Tests**: Tests that verify fixes for common issues
#
# ### YAML Configuration
#
# Test settings are managed via YAML files in `config/test/`:
# - `execution.yaml`: Coverage thresholds, markers, performance settings
# - `fixtures.yaml`: Test data fixtures
# - `mocks.yaml`: Mock component settings
# - `environments.yaml`: Environment-specific settings
#
# See [tests/README_YAML_CONFIG.md](../tests/README_YAML_CONFIG.md) for details.
#
# ### Documentation
#
# See [TESTING.md](../docs/TESTING.md) for detailed testing documentation.
# See [TROUBLESHOOTING.md](../docs/TROUBLESHOOTING.md) for common issues and fixes.
